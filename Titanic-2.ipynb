# %%
import numpy as np  #linear algebra
import pandas as pd  #data processing , CSV files I/O

# %%
data=pd.read_csv("tested.csv" ,delimiter=',') #read given CSV data
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.shape
# Out:
# (418, 12)

# %%
data.isna().sum()  #total nulls identify
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data.info() #total information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.dtypes   #checking data types of the data
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.head()  #showing first 5 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail()  #showing last 5 rows of data
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
import pyforest

# %%
sandy=data.rename(columns={'Sex':'Gender'},inplace=True)  #rename specify columns
sandy

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Gender   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#import label encoder
from sklearn import preprocessing

#label_encoder object knows how to understand word lables.
label_encoder = preprocessing.LabelEncoder()

#Encode label in column "Gender"
data['Gender']=label_encoder.fit_transform(data['Gender'])

#convrting male as 1 and female as 0
data['Gender'].value_counts()
# Out:
# 1    266
# 0    152
# Name: Gender, dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James       1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)       0  47.0      1      0
# 2                       Myles, Mr. Thomas Francis       1  62.0      0      0
# 3                                Wirz, Mr. Albert       1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)       0  22.0      1      1
# ...

# %%
#import label encoder
from sklearn import preprocessing

#label_encoder object knows how to understand word lables.
label_encoder = preprocessing.LabelEncoder()

#Encode label 
data['Embarked']=label_encoder.fit_transform(data['Embarked'])

#conerting 0,1,2
data['Embarked'].value_counts()
# Out:
# 2    270
# 0    102
# 1     46
# Name: Embarked, dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James       1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)       0  47.0      1      0
# 2                       Myles, Mr. Thomas Francis       1  62.0      0      0
# 3                                Wirz, Mr. Albert       1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)       0  22.0      1      1
# ...

# %%
data=data.drop(['Ticket','Cabin','Name'],axis=1)  #remove unwanted columns
data
# Out:
#      PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch      Fare  \
# 0            892         0       3       1  34.5      0      0    7.8292
# 1            893         1       3       0  47.0      1      0    7.0000
# 2            894         0       2       1  62.0      0      0    9.6875
# 3            895         0       3       1  27.0      0      0    8.6625
# 4            896         1       3       0  22.0      1      1   12.2875
# ..           ...       ...     ...     ...   ...    ...    ...       ...
# 413         1305         0       3       1   NaN      0      0    8.0500
# 414         1306         1       1       0  39.0      0      0  108.9000
# 415         1307         0       3       1  38.5      0      0    7.2500
# 416         1308         0       3       1   NaN      0      0    8.0500
# 417         1309         0       3       1   NaN      1      1   22.3583
#
#      Embarked
# 0           1
# 1           2
# 2           1
# 3           2
# ...

# %%
data['Age'].median()  #median of Age
# Out:
# 27.0

# %%
#filling the null values using "fillna"
data['Age']=data['Age'].fillna(value=27)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch      Fare  \
# 0            892         0       3       1  34.5      0      0    7.8292
# 1            893         1       3       0  47.0      1      0    7.0000
# 2            894         0       2       1  62.0      0      0    9.6875
# 3            895         0       3       1  27.0      0      0    8.6625
# 4            896         1       3       0  22.0      1      1   12.2875
# ..           ...       ...     ...     ...   ...    ...    ...       ...
# 413         1305         0       3       1  27.0      0      0    8.0500
# 414         1306         1       1       0  39.0      0      0  108.9000
# 415         1307         0       3       1  38.5      0      0    7.2500
# 416         1308         0       3       1  27.0      0      0    8.0500
# 417         1309         0       3       1  27.0      1      1   22.3583
#
#      Embarked
# 0           1
# 1           2
# 2           1
# 3           2
# ...

# %%
data['Age'].isna().sum()  #checking total nulls in 'Age' column
# Out:
# 0

# %%
data.isna().sum()  #checking total nulls in 'data'
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Gender         0
# Age            0
# SibSp          0
# Parch          0
# Fare           1
# Embarked       0
# dtype: int64

# %%
#Remove null values in Rows 
data.dropna(axis=0,inplace=True)
#inplace : If it is  True ,then it replace in place.

# %%
data.isnull().sum() #checking total nulls in 'data'
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Gender         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch      Fare  \
# 0            892         0       3       1  34.5      0      0    7.8292
# 1            893         1       3       0  47.0      1      0    7.0000
# 2            894         0       2       1  62.0      0      0    9.6875
# 3            895         0       3       1  27.0      0      0    8.6625
# 4            896         1       3       0  22.0      1      1   12.2875
# ..           ...       ...     ...     ...   ...    ...    ...       ...
# 413         1305         0       3       1  27.0      0      0    8.0500
# 414         1306         1       1       0  39.0      0      0  108.9000
# 415         1307         0       3       1  38.5      0      0    7.2500
# 416         1308         0       3       1  27.0      0      0    8.0500
# 417         1309         0       3       1  27.0      1      1   22.3583
#
#      Embarked
# 0           1
# 1           2
# 2           1
# 3           2
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import figure
style.use('fivethirtyeight')

# %%
sns.countplot(data['Survived'],hue=data['Embarked'])
plt.show
# Out:
# C:\Users\91630\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data['Embarked'],hue=data['Survived'])
plt.show
# Out:
# C:\Users\91630\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data['Survived'],hue=data['Gender'])
plt.show
# Out:
# C:\Users\91630\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data['SibSp'],hue=data['Survived'])
plt.show
# Out:
# C:\Users\91630\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.corr()
# Out:
#              PassengerId  Survived    Pclass    Gender       Age     SibSp  \
# PassengerId     1.000000 -0.024117 -0.025800  0.024117 -0.028926  0.003259
# Survived       -0.024117  1.000000 -0.107203 -1.000000  0.012547  0.099136
# Pclass         -0.025800 -0.107203  1.000000  0.107203 -0.476790  0.002136
# Gender          0.024117 -1.000000  0.107203  1.000000 -0.012547 -0.099136
# Age            -0.028926  0.012547 -0.476790 -0.012547  1.000000 -0.068791
# SibSp           0.003259  0.099136  0.002136 -0.099136 -0.068791  1.000000
# Parch           0.042650  0.158534  0.019581 -0.158534 -0.041699  0.306566
# Fare            0.008211  0.191514 -0.577147 -0.191514  0.347105  0.171539
# Embarked        0.041521 -0.075106  0.226856  0.075106 -0.153328  0.053595
#
#                 Parch      Fare  Embarked
# PassengerId  0.042650  0.008211  0.041521
# Survived     0.158534  0.191514 -0.075106
# Pclass       0.019581 -0.577147  0.226856
# Gender      -0.158534 -0.191514  0.075106
# ...

# %%
data.plot(x='Survived',y=['SibSp','Parch'],kind='barh')
plt.show()

# %%
data.plot(x='Survived',y=['SibSp','Parch'],kind='bar')
plt.show()

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data['family']=data['Age']+data['Gender']+0.00
data=data.drop('Parch',axis=1)
data=data.drop('PassengerId',axis=1)
data=data.drop('Embarked',axis=1)
data=data.drop('SibSp',axis=1)
data
# Out:
#      Survived  Pclass  Gender   Age      Fare  family
# 0           0       3       1  34.5    7.8292    35.5
# 1           1       3       0  47.0    7.0000    47.0
# 2           0       2       1  62.0    9.6875    63.0
# 3           0       3       1  27.0    8.6625    28.0
# 4           1       3       0  22.0   12.2875    22.0
# ..        ...     ...     ...   ...       ...     ...
# 413         0       3       1  27.0    8.0500    28.0
# 414         1       1       0  39.0  108.9000    39.0
# 415         0       3       1  38.5    7.2500    39.5
# 416         0       3       1  27.0    8.0500    28.0
# 417         0       3       1  27.0   22.3583    28.0
#
# [417 rows x 6 columns]

# %%
x=data.drop('Survived',axis=1).values
y=data['Survived'].values

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

# %%
from sklearn.metrics import accuracy_score

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
lrpred=lr.predict(x_test)

# %%
accuracy_score(y_test,lrpred)
# Out:
# 1.0

# %%
from sklearn.model_selection import GridSearchCV

c_space=np.logspace(-5,8,15)
param_grid={'C':c_space}

logreg_cv=GridSearchCV(lr,param_grid,cv=5)

logreg_cv.fit(x_train,y_train)

print("Tuned Logistic Regression: {}".format(logreg_cv.best_params_))
print('Best score is {}'.format(logreg_cv.best_score_))
# Out:
# Tuned Logistic Regression: {'C': 0.4393970560760795}
# Best score is 1.0
